# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Евгения, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провела хорошую работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Евгения, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделала огромную работу :)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Путь к файлу: /datasets/real_estate_data.csv
#
# Загрузите данные из csv-файла в датафрейм c помощью библиотеки pandas.
#
# Изучите общую информацию о полученном датафрейме.
#
# Постройте гистограмму для всех числовых столбцов таблицы на одном графике. Например, для датафрейма data можно построить такую гистограмму командой data.hist(figsize=(15, 20)). Напомним, что параметр figsize задаёт размер графика.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Импорт всех библиотек лучше делать в одной отдельной ячейке, чтобы при необходимости можно было ее перезапустить без влияния на другой код и без перезаписи датасета. </div>
#
# ✔

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv',sep='\t')
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
#    При первом взгляде на данные можно отметить 2 момента:
#
# - в исходных данных использовался разделитель "\t";
# - как минимум, в 11 столбцах присутствуют пропуски в данных.
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# - только в 8 столбцах все строки содержат в себе данные;
# - в той части данных, которые вносились пользователи, помимо пропусков могут быть ошибки и скрытые дубли;
# - в той части, которая получена автоматически, довольно высокая доля пропусков - причины их возникновения было бы полезно выяснить отдельно.
#
# </div>

# %% [markdown]
# Описание данных:
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После каждого пункта нужно делать промежуточный вывод.
#
# Что мы можем сказать о данных после первичного знакомства  с ними?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Исходя из имеющихся данных и построенным по ним графикам опишем наши наблюдения:
#
# 1. Объявления содержат в себе обычно около 10-15 фотографий.
# 2. У всех объявлений указана цена.
# 3. Общая площадь большинства квартир до 100 кв. м., но встречаются квартиры бОльшей площади - до 300 кв. м. (их меньшинство).
# 4. В квартирах в основном до 5ти комнат, но есть квартиры и с бОльшим количеством комнат (их меньшинство).
# 5. Высота потолков указана не во всех объявлениях.
# 6. Этажность домов, в которых продаются квартиры,не превышает 40ка этажей. Большая часть домов - до 20ти этажей.
# 7. Жилая площадь большинства квартир - до 50ти кв. м.
# 8. График по столбцу "floor" - соответствует распределению Пуассона. Большая часть квартир находится в  диапазоне до 10 этажей.
# 9. Площадь кухонь в основном не превышает 12,5 кв. м.
# 10. По балконам чаще всего встречаются 3 варианта - без балконов, с 1 и с 2мя балконами. Остальные варианты не являются типичными.
# 11. Расстояние от продаваемых квартир до ближайшего аэропорта не превышает 80 км.
# 12. Расстояние от продаваемых квартир до центра города в основном не превышает 20 км.
# 13. Почти у 10 тыс. продаваемых квартир нет в шаговой доступности ни одного парка.
# 14. Похожая картина с доступностью водоемов.
# 15. Срок размещения объявления соответствует распределению Пуассона. Стоит обратить внимание на аномально короткие (близко к 0 дней) и аномально длинные сроки размещения объявлений (близко к 1000+ дней).
#
# </div>

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# 2.1 Найдите и изучите пропущенные значения в столбцах:
#
# - Определите, в каких столбцах есть пропуски.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# - в 8ми столбцах заполнены все данные;
# - в 14ти столбцах есть пропуски, из них:
#     - в 7 столбцах можно заполнить пропуски с помощью логики и расчетов, т.к. данные в них вводились людьми вручную: ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name;
#     - в столбцах airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000 и ponds_nearest данные автоматически получены из геосервисов, поэтому будем анализировать их в том виде, в котором они поступили;
#     - в столбце days_exposition пропуски могли возникнуть по причине того, что объявления о продаже не были закрыты на момент выгрузки. Т.е. владельцы этих объявлений с высокой долей вероятности еще не нашли покупателей выставленных на продажу квартир.
#
# </div>

# %% [markdown]
# - Заполните пропущенные значения там, где это возможно. Если логичную замену предложить невозможно, то оставьте пропуски. Пропущенные значения — тоже важный сигнал, который нужно учитывать.

# %% [markdown]
# 2.1.1 Заполняем пропуски в столбце locality_name.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Пропуски в locality_name можно заполнить значением "Неизвестный город", т.к. наименование города, где продается квартира, нам неизвестно. Также можно заполнить пропуски значением "Санкт-Петербург", т.к. оно встречается в выборке чаще всего - в 66%, а кол-во пропусков статистически незначительно - меньше 1%.
#
# </div>

# %%
data['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %%
data['locality_name'] = data['locality_name'].fillna('Санкт-Петербург')
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# 2.1.2 Заполняем пропуски в столбце floors_total.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Пропуски в столбце floors_total можно заполнить медианной, округленной до целого, этажностью в каждом городе, т.е. наиболее типичной для него.
#
# </div>

# %%
for d in data['locality_name'].unique():
    data.loc[(data['locality_name'] == d) & (data['floors_total'].isna()), 'floors_total'] = round(data.loc[(data['locality_name'] == d), 'floors_total'].median())

len(data[data['floors_total'].isna()])
# Out:
# 0

# %%
data['floors_total'].value_counts()
# Out:
# 5.0     5789
# 9.0     3833
# 16.0    1377
# 12.0    1363
# 4.0     1201
# 10.0    1174
# 25.0    1075
# 6.0      917
# 17.0     833
# 3.0      668
# 7.0      592
# 14.0     554
# 18.0     507
# 24.0     469
# 8.0      390
# 2.0      383
# 15.0     365
# 23.0     352
# 19.0     341
# 22.0     286
# 20.0     273
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 37.0       1
# 34.0       1
# 33.0       1
# 60.0       1
# 29.0       1
# 52.0       1
# Name: floors_total, dtype: int64

# %%
data['floors_total'] = data['floors_total'].astype('int')

# %%
data.loc[data['floors_total'] < data['floor'],'floors_total'] = data.loc[data['floors_total'] < data['floor'],'floor']

# %% [markdown]
# 2.1.3 Заполняем пропуски в столбце ceiling_height.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Мы можем для каждой группы домов одной этажности вычислить наиболее характерную высоту потолков, т.е. медиану.
# Полученные значения мы сможем внести на место пропусков в столбце ceiling_height, ориентируясь на кол-во этажей в доме, которое указано для каждого объявления по итогам шага 2.1.2.
#
# </div>

# %%
for d in data['floors_total'].unique():
    data.loc[(data['floors_total'] == d) & (data['ceiling_height'].isna()), 'ceiling_height'] = data.loc[(data['floors_total'] == d), 'ceiling_height'].median()
len(data[data['ceiling_height'].isna()])
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# 1

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Очень не хватает твоих комметариев ,по какому принципу и почему именно так заполняются пропуски. Читатель исследования не поймет какая работа проводится и для чего.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data[data['ceiling_height'].isna()].head()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11575             9   9900000.0       101.0  2016-04-28T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 11575             NaN            33         53.0     32        False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 11575          21.0      0.0  Санкт-Петербург           18732.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 11575             20444.0               0.0            NaN               3.0
#
#        ponds_nearest  days_exposition
# 11575           80.0             53.0
#
# [1 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# В столбце ceiling_height остался 1 пропуск. В базе данных не оказалось домов с похожей этажностью.
# Этот пропуск заполним вручную, присвоив медианное значение, т.к. жилье строится по определенным стандартам и выход за них хоть и возможен, но маловероятен.
#
# </div>

# %%
data.loc[11575,'ceiling_height'] = data['ceiling_height'].median()
len(data[data['ceiling_height'].isna()])
# Out:
# 0

# %% [markdown]
# 2.1.4 Заполняем пропуски в столбце kitchen_area.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
#    Для заполнения пропусков в столбце kitchen_area проанализируем какую долю в общей площади квартиры обычно занимает площадь кухни.
#
# </div>

# %%
data['kitchen_area_ratio'] = data['kitchen_area']/data['total_area']
data['kitchen_area_ratio'].describe()
# Out:
# count    21421.000000
# mean         0.187355
# std          0.072968
# min          0.025381
# 25%          0.133333
# 50%          0.172414
# 75%          0.232416
# max          0.787879
# Name: kitchen_area_ratio, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Получили среднюю долю площади кухни по отношению к общей площади квартиры - 18,74%. Применим его для заполнения пропусков в kitchen_area.
#
# </div>

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area']*0.1874)

len(data[data['kitchen_area'].isna()])
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Разве может площадь кухни зависеть от количества этажей в доме?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Видимо нет, исправила.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# 2.1.5 Заполняем пропуски в столбце living_area.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Для заполнения пропусков в столбце living_area используем такую же логику вычислений как и в kitchen_area.
#
# </div>

# %%
data['living_area_ratio'] = data['living_area']/data['total_area']
data['living_area_ratio'].describe()
# Out:
# count    21796.000000
# mean         0.564766
# std          0.105368
# min          0.021583
# 25%          0.495177
# 50%          0.567860
# 75%          0.637880
# max          1.000000
# Name: living_area_ratio, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Получили среднюю долю жилой площади по отношению к общей площади квартиры - 56,47%. Применим его для заполнения пропусков в living_area.
#
# </div>

# %%
data['living_area'] = data['living_area'].fillna(data['total_area']*0.5647)

len(data[data['living_area'].isna()])
# Out:
# 0

# %%
# код ревьюера
data[(data['living_area']+data['kitchen_area']) > data['total_area']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7   2600000.0       30.20  2018-02-14T00:00:00      1
# 424              14  11500000.0       98.00  2016-05-10T00:00:00      3
# 440               8   2480000.0       27.11  2018-03-12T00:00:00      0
# 545               9   4700000.0       23.80  2018-12-28T00:00:00      1
# 551               8   3100000.0       31.59  2018-03-08T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22246             6   3100000.0       27.30  2018-05-29T00:00:00      0
# 22907             9  65000000.0      228.00  2016-06-02T00:00:00      4
# 23102             0   5800000.0       66.00  2017-06-09T00:00:00      5
# 23191             3   1900000.0       18.90  2016-04-04T00:00:00      1
# 23202            13   4919880.0       67.92  2018-10-23T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.loc[(data['living_area']+data['kitchen_area']) > data['total_area'], 'living_area'] = data.loc[(data['living_area']+data['kitchen_area']) > data['total_area'], 'total_area']*0.5647
data.loc[(data['living_area']+data['kitchen_area']) > data['total_area'], 'kitchen_area'] = data.loc[(data['living_area']+data['kitchen_area']) > data['total_area'], 'kitchen_area']*0.1874
data[(data['living_area']+data['kitchen_area']) > data['total_area']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, kitchen_area_ratio, living_area_ratio]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Получили 716 квартир, у которых сумма жилой площади и площади кухни больше общей.
#
# Пропуски можно заполнить так: сначала вычисляем среднее отношение жилой площади к общей, это будет наш коэффициент жилой площади. Далее в строках с пропусками умножаем общую площадь на этот коэффициент, получая жилую площадь.
#
# Подобным образом можно заполнить пропуски и в столбце с площадью кухни.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Пропуски в площадях заполнены, ошибоочные значения заменены.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# 2.1.6 Заполняем пропуски в столбце balcony.
# Если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0.

# %%
len(data[data['balcony'].isna()])
# Out:
# 11519

# %%
data['balcony'] = data['balcony'].fillna(0)
data['balcony'] = data['balcony'].astype('int')
len(data[data['balcony'].isna()])
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Если столбец должен быть числового типа, то и пропуски следует заполнять значениями числового типа.</div>
#
# ✔

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# 2.1.7 Заполняем пропуски в столбце is_apartment.

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
data['is_apartment'] = data['is_apartment'].fillna(0)
data['is_apartment'] = data['is_apartment'].astype('bool')
len(data[data['is_apartment'].isna()])
# Out:
# 0

# %%
data['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Данный столбец должен быть булева типа. Ты заполняешь пропуски строковым значением и при изменении типа на булев эти значения вместо нужных `False` станут `True`
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# В столбце is_apartment данные были заполнены частично: True значит, что продаваемый объект является апартаментами, False - то, что объект апартаментами не является.
#
# На рынке недвижимости подавляющее большинство объектов являются обычными квартирами, апартаменты - явление редкое. Поэтому все пропуски мы заполнили значением False. Дополнительно мы поменяли тип данных с object на bool.
#
# </div>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# kitchen_area_ratio       2278
# living_area_ratio        1903
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Что можно сказать о пропусках в остальных столбцах ,можем ли мы их заполнить? Если нет, то почему?
#
# </div>
#
# см. ниже

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# - В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Итак, мы заполнили пропуски в 7 столбцах: ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name. Пропуски могли возникнуть по следующим причинам:
#
# - данные могли не указать как не существенные / были введены с ошибкой / не были распознаны в столбцах: ceiling_height, floors_total, locality_name, living_area, kitchen_area;
# - не заполнением поля могли подразумевать отрицательный ответ / отсутствие: is_apartment, balcony.
#
# В столбцах airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest могли по каким-либо причинам не загрузиться нужные нам данные из геосервисов. Их нужно будет выяснять отдельно, например у специалистов, которые готовили выгрузку этих данных.
#
# В столбце days_exposition пропуски возможно вызваны тем, что объявления были все еще открыты на момент выгрузки.
#
# </div>

# %% [markdown]
# 2. Рассмотрите типы данных в каждом столбце:
#
# - Найдите столбцы, в которых нужно изменить тип данных.
#
# - Преобразуйте тип данных в выбранных столбцах.
#
# - В ячейке с типом markdown поясните, почему нужно изменить тип данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Меняем тип данных:
# - first_day_exposition с object на datetime для дальнейшей обработки дат (вынесем в отдельный столбец - date).
#
# Ранее меняли типы данных:
# - floors_total с float64 на int64, т.к. количество этажей - это целое число;
# - balcony с float64 на int64, т.к. количество балконов - это целое число;
# - is_apartment с object на bool, т.к. в этом столбце возможны только 2 варианта - True / False (т.е. является апартаментами или нет).
# </div>

# %%
data['date'] = pd.to_datetime(data['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# 3. Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
len(data['locality_name'].unique())
# Out:
# 364

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('коттеджный поселок', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('садоводческое некоммерческое товарищество', 'садовое товарищество')
data['locality_name'] = data['locality_name'].str.replace('поселок Мурино', 'Мурино')

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'поселок Янино-1',
#        'поселок Парголово', 'Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Федоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок Лебяжье', 'поселок Сиверский',
#        'поселок Молодцово', 'поселок Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок Ефимовский', 'поселок Плодовое', 'деревня Заклинье',
#        'поселок Торковичи', 'поселок Первомайское', 'Красное Село',
#        'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'поселок Новый Свет', 'Сланцы',
#        'село Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
# ...

# %%
len(data['locality_name'].unique())
# Out:
# 320

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Сначала лучше заменить все буквы ё на е, чтобы не делать лишних действий</div>
#
# ✔

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# В этом пункте можно дополнительно сравнить количество неявных дубликатов до обработки названий населенных пунктов и после, чтобы увидеть результат проведенной работы. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# По итогам работы со столбцом locality_name количество уникальных значений уменьшилось с 364 до 320.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# Добавьте в таблицу новые столбцы со следующими параметрами:
#
# - цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %%
data['one_metre_cost'] = round(data['last_price']/data['total_area'], 2)
    
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16      51.0000      8         False  ...
# 1            2.75            11      18.6000      1         False  ...
# 2            2.55             5      34.3000      4         False  ...
# 3            2.60            14      89.7873      9         False  ...
# 4            3.03            14      32.0000     13         False  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %%
data['weekday'] = data['date'].dt.weekday
data['month'] = data['date'].dt.month
data['year'] = data['date'].dt.year

data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16      51.0000      8         False  ...
# 1            2.75            11      18.6000      1         False  ...
# 2            2.55             5      34.3000      4         False  ...
# 3            2.60            14      89.7873      9         False  ...
# 4            3.03            14      32.0000     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  kitchen_area_ratio  \
# ...

# %%
# тип этажа квартиры (значения — «первый», «последний», «другой»)
# если № этажа 1, то первый
# если № этажа больше 1 и меньше к-ва этажей в доме, то другой
# если № этажа равен кол-ву этажей в доме, то последний
# иначе - ошибка

def categorize_floor(row):
    if row['floor'] == row['floors_total']:
        return 'последний'
    if 1 < row['floor'] < row['floors_total']:
        return 'другой'
    if row['floor'] == 1:
        return 'первый'
    return 'ошибка'

# %%
data['category_floor'] = data.apply(categorize_floor, axis=1)
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16     51.00000      8         False  ...
# 1            2.75            11     18.60000      1         False  ...
# ...

# %%
#расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).
data['cityCenters_nearest'].head(5)
# Out:
# 0    16028.0
# 1    18603.0
# 2    13933.0
# 3     6800.0
# 4     8098.0
# Name: cityCenters_nearest, dtype: float64

# %%
data['cityCenters_nearest'] = round(data['cityCenters_nearest']/1000)
data['cityCenters_nearest'].head(5)
# Out:
# 0    16.0
# 1    19.0
# 2    14.0
# 3     7.0
# 4     8.0
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Дополнительные данные рассчитаны и добавлены верно!  </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# 1. Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров. В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
#
# Список параметров:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка.
#
# Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
plt.ylabel("кв.м.")
plt.xlabel("общая площадь")
plt.ylim(0, 150)
data.boxplot(column='total_area')

plt.show()

# %% [markdown]
# В колонке с информацией об общей площади продаваемых квартир большая часть значений находится в диапазоне от 15 (комнаты, студии) до 115 кв. м. (4х-комнатные квартиры).
# Помимо этого в выборке присутствуют выбросы - квартиры от 115 кв. м. и выше действительно встречаются на рынке значительно реже.

# %%
plt.xlabel("total_area (общая площадь)")
plt.ylabel("количество объектов")
data['total_area'].hist(range=(20, 120), bins=50)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Необходимо подписывать каждый график и оси на нем. Есть [хорошая статья](https://devpractice.ru/matplotlib-lesson-3-3-text-elements/), которая подскажет как это правильно сделать). </div>
#
# ✔

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
#
#
# Названия для графиков тоже необходимо подписывать</div>

# %% [markdown]
# - В базе данных собраны квартиры общей площадью от 12 до 900 кв. м.
# - Основная масса квартир имеет площадь от 30 до 115 кв. м.
# - На графике видем выраженное пиковое значение на уровне 45 кв. м., что соответствует 2х-комнатной квартире в старых домах или 1-комнатной квартире в новых домах.

# %%
data['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.492437
# std         22.268741
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.000000
# max        409.700000
# Name: living_area, dtype: float64

# %%
plt.xlabel("жилая площадь")
plt.ylabel("кв.м.")
plt.ylim(0, 80)
data.boxplot(column='living_area')
plt.show()

# %% [markdown]
# В колонке с информацией о жилой площади продаваемых квартир большая часть значений находится в диапазоне от 2 до 75 кв. м.
#
# 2 кв. м. жилой площади выглядит не реалистично, т.к. минимальный размер жилой комнаты обычно 10 кв. м.
#
# Также в выборке присутствуют выбросы - от 75 кв. м. жилой площади.

# %%
#скорректируем аномально низкие значения жилой площади
data.loc[data['living_area'] < 10.0, 'living_area'] = data.loc[data['living_area'] < 10.0, 'total_area']*0.5647
data.loc[data['living_area'] < 10.0, 'living_area']
# Out:
# 9157     9.93872
# 12040    8.47050
# 16949    8.47050
# 17961    7.34110
# 19546    7.34110
# 19558    7.45404
# 19904    6.77640
# 22356    9.71284
# Name: living_area, dtype: float64

# %%
data['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.510169
# std         22.257911
# min          6.776400
# 25%         19.000000
# 50%         30.000000
# 75%         42.000000
# max        409.700000
# Name: living_area, dtype: float64

# %%
plt.xlabel("жилая площадь")
plt.ylabel("кв.м.")
plt.ylim(0, 80)
data.boxplot(column='living_area')
plt.show()

# %%
plt.xlabel("living_area (жилая площадь)")
plt.ylabel("количество объектов")
data['living_area'].hist(range=(0, 100), bins=100)
plt.show()

# %% [markdown]
# - В базе данных собраны квартиры с жилой площадью от 7 до 409,7 кв. м.
# - Основная масса квартир имеет жилую площадь от 15 до 60 кв. м.
# - Выделяются 2 группы квартир:
# 1) площадью от 10 до 23 кв. м. (скорее всего однокомнатные);
# 2) площадью от 25 кв. м. и выше (многокомнатные).

# %%
data['kitchen_area'].describe()
# Out:
# count    23699.000000
# mean        10.554858
# std          6.069630
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
#скорректируем аномально низкие значения площади кухни
data.loc[data['kitchen_area'] < 7.0, 'kitchen_area'] = data.loc[data['kitchen_area'] < 7.0, 'total_area']*0.1874
data.loc[data['kitchen_area'] < 7.0, 'kitchen_area']
# Out:
# 18       5.80940
# 21       5.92184
# 23       5.99680
# 30       6.14672
# 49       5.77192
#           ...
# 23673    4.31020
# 23679    6.55900
# 23685    5.80940
# 23686    5.80940
# 23692    5.62200
# Name: kitchen_area, Length: 2130, dtype: float64

# %%
data['kitchen_area'].describe()
# Out:
# count    23699.000000
# mean        11.024702
# std          5.859357
# min          2.248800
# 25%          8.000000
# 50%          9.900000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
plt.xlabel("площадь кухни")
plt.ylabel("кв.м.")
plt.ylim(0, 25)
data.boxplot(column='kitchen_area')
plt.show()

# %% [markdown]
# В колонке с информацией о площади кухни продаваемых квартир большая часть значений находится в диапазоне от 2,24 до 17 кв. м. Изначально минимум был - 1,3 кв. м. площади кухни, что выглядело не реалистично, т.к. минимальный размер кухни обычно 6 кв. м. Также в выборке присутствуют выбросы - от 19 кв. м. жилой площади. Это могут быть кухни, объединенные с гостинной.

# %%
len(data.loc[data['kitchen_area'] < 4.0, 'kitchen_area'])
# Out:
# 49

# %% [markdown]
# Это вполне могут быть кухни-ниши в квартирах-студиях.

# %%
len(data.loc[data['kitchen_area'] > 16.0, 'kitchen_area'])
# Out:
# 2234

# %%
data.query('16 < kitchen_area < 25.0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 24                8   6500000.0       97.20  2015-10-31T00:00:00      2
# 35                6  15500000.0      149.00  2017-06-26T00:00:00      5
# 42               13  22000000.0      161.80  2015-07-08T00:00:00      4
# 61               18   7990000.0       74.00  2017-08-24T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23590             0  21187872.0      123.30  2017-04-25T00:00:00      3
# 23646            10   8200000.0       68.70  2018-12-03T00:00:00      2
# 23647             9   5700000.0       45.60  2019-01-09T00:00:00      1
# 23663            12   6400000.0       88.00  2018-01-12T00:00:00      4
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# При проведении ислледовательского анализа нам нужно обработать аномальные  и выбивающиеся значения.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Нижнюю границу обработали - она поднялась.
#
# По верхней границе есть 2 предположения:
#
# 1) поскольку около половины значений выше нормы входит в диапазон от 16 до 26 кв. м., то это вполне могут быть кухни, объединенные с гостинной.
#
# 2) остальная часть аномально больших кухонь может приходиться на стольже аномально большие квартиры.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
plt.xlabel("kitchen_area (площадь кухни)")
plt.ylabel("количество объектов")
data['kitchen_area'].hist(range=(0, 60), bins=30)
plt.show()

# %% [markdown]
# В базе данных собраны квартиры с площадью кухни от 2.24 до 112 кв. м. Основная масса квартир имеет площадь кухни от 5 до 16 кв. м.

# %%
# переведем цены в млн. рублей
data['last_price'] = data['last_price']/1000000
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0  2019-03-07T00:00:00      3
# 1             7       3.350        40.4  2018-12-04T00:00:00      1
# 2            10       5.196        56.0  2015-08-20T00:00:00      2
# 3             0      64.900       159.0  2015-07-24T00:00:00      3
# 4             2      10.000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16      51.0000      8         False  ...
# 1            2.75            11      18.6000      1         False  ...
# 2            2.55             5      34.3000      4         False  ...
# 3            2.60            14      89.7873      9         False  ...
# 4            3.03            14      32.0000     13         False  ...
#
#    ponds_nearest  days_exposition  kitchen_area_ratio  living_area_ratio  \
# ...

# %%
data['last_price'].describe()
# Out:
# count    23699.000000
# mean         6.541549
# std         10.887013
# min          0.012190
# 25%          3.400000
# 50%          4.650000
# 75%          6.800000
# max        763.000000
# Name: last_price, dtype: float64

# %%
plt.xlabel("цена")
plt.ylabel("млн. руб.")
plt.ylim(0, 15)
data.boxplot(column='last_price')
plt.show()

# %% [markdown]
# Основная масса квартир находится в ценовом диапазоне от 3,4 до 12 млн. рублей.
# От 12 млн. рублей - вероятно выбросы, например это квартиры с большой площадью, квартиры из элитного сегмента или квартиры с завышенными ценами.
# Также необычно выглядят объекты с ценой около 1 млн. рублей и ниже. Возможно это доли в квартирах или просто комнаты.

# %%
plt.xlabel("last_price (цена, млн. руб.)")
plt.ylabel("количество объектов")
data['last_price'].hist(range= (0,17), bins=17)
plt.show()

# %% [markdown]
# Основная масса квартир продается с ценой от 2,5х до 12 млн. рублей.

# %%
data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
plt.xlabel("комнаты")
plt.ylabel("количество комнат")
data.boxplot(column='rooms', figsize=(5,5))
plt.show()

# %%
plt.xlabel("rooms (кол-во комнат)")
plt.ylabel("количество объектов")
data['rooms'].hist(range=(1, 6), bins=6)
plt.show()

# %% [markdown]
# У основной массы квартир до 6ти комнат.
# Преобладают квартиры с 1-3мя комнатами.

# %%
data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.735625
# std          0.994299
# min          1.000000
# 25%          2.550000
# 50%          2.650000
# 75%          2.750000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
plt.ylabel("высота потолков, м.")
data.boxplot(column='ceiling_height', figsize=(3, 10))
plt.show()

# %%
# изучим и скорректируем значения аномально высоких потолков
data.query('ceiling_height > 10')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17       3.600        55.2  2018-07-12T00:00:00      2
# 397              15       5.990        54.0  2018-03-22T00:00:00      2
# 3148             14       2.900        75.0  2018-11-12T00:00:00      3
# 4643              0       4.300        45.0  2018-02-01T00:00:00      2
# 4876              7       3.000        25.0  2017-09-27T00:00:00      0
# 5076              0       3.850        30.5  2018-10-03T00:00:00      1
# 5246              0       2.500        54.0  2017-10-13T00:00:00      2
# 5669              4       4.400        50.0  2017-08-08T00:00:00      2
# 5807             17       8.150        80.0  2019-01-09T00:00:00      2
# 6246              6       3.300        44.4  2019-03-25T00:00:00      2
# 9379              5       3.950        42.0  2017-03-26T00:00:00      3
# 10773             8       3.800        58.0  2017-10-13T00:00:00      2
# ...

# %%
wrong_ceiling_height = data[data['ceiling_height'] > 11]['ceiling_height'].unique()

for i in wrong_ceiling_height:
    data['ceiling_height'] = data['ceiling_height'].replace(i, i / 10)

# %%
plt.ylabel("высота потолков, м.")
data.boxplot(column='ceiling_height', figsize=(2, 5))
plt.show()

# %%
plt.xlabel("высота потолка")
plt.ylabel("количество объектов")
data['ceiling_height'].hist()
plt.show()

# %% [markdown]
# У большинства квартир высота потолков варьируется от 2,5 до 3,5 м.

# %%
plt.xlabel("категория этажа")
plt.ylabel("количество объектов")
data['category_floor'].hist()
plt.show()

# %%
data['category_floor'].value_counts()
# Out:
# другой       17409
# последний     3398
# первый        2892
# Name: category_floor, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# В какую выборку? Почему ты не исключаешь эти строки?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Уже не актуально, исправила решение и строк с "ошибкой" больше нет.
#
# В данных преобладают квартиры, расположенные в середине домов, что ожидаемо.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['floors_total'].describe()
# Out:
# count    23699.000000
# mean        10.680324
# std          6.592839
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
plt.ylabel("количество этажей")
data.boxplot(column='floors_total', figsize=(5,5))
plt.show()

# %%
plt.xlabel("количество этажей в доме")
plt.ylabel("количество объектов")
data['floors_total'].hist(range=(1,30), bins=30)
plt.show()

# %% [markdown]
# В выборке есть дома различной этажности: от 1 до 60.
# Основная масса домов - до 28 этажей.
# Наиболее распространены 5-ти и 9-ти этажные дома, которые в свое время строились массово.

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    18180.000000
# mean        14.184818
# std          8.616194
# min          0.000000
# 25%          9.000000
# 50%         13.000000
# 75%         16.000000
# max         66.000000
# Name: cityCenters_nearest, dtype: float64

# %%
plt.ylabel("расстояние до центра, км.")
data.boxplot(column='cityCenters_nearest', figsize=(5,5))
plt.show()

# %%
plt.xlabel("расстояние до центра, км.")
plt.ylabel("количество объектов")
data['cityCenters_nearest'].hist(bins=20)
plt.show()

# %% [markdown]
# Основная масса продаваемых квартир находится в 15-километровой доступности от центра.

# %%
data['parks_nearest'].describe()
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
plt.ylabel("расстояние до парков, м.")
data.boxplot(column='parks_nearest', figsize=(5,5))
plt.show()

# %%
plt.xlabel("расстояние до парков, м.")
plt.ylabel("количество объектов")
data['parks_nearest'].hist(bins=20)
plt.show()

# %% [markdown]
# Квартиры, по которым есть данные по расстоянию до ближайшего парка, расположены в основном не более, чем в 1 км от зеленой зоны.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что сделала уточнение о наличии данных по расстоянию. </div>

# %% [markdown]
# 2. Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
#
# - Постройте гистограмму.
# - Посчитайте среднее и медиану.
# - В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.ylabel("дни размещения объявления")
plt.ylim(0, 600)
data.boxplot(column='days_exposition', figsize=(5,5))
plt.show()

# %%
plt.xlabel("дни размещения объявления")
plt.ylabel("количество объектов")
data['days_exposition'].hist(bins=50)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Напомню, что каждый график в проекте и оси на нем должны быть подписаны</div>
#
# ✔

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
#
# Не забывай подписывать заголовки для графиков</div>

# %% [markdown]
# Продажа обычно занимает от 1,5 до 8 месяцев.
# На гистограмме мы видим 2 "плеча":
# - с аномально быстрыми продажами, срок стремится к 0;
# - с аномально долгими продажами, у которых срок превышает 1 год и 3 месяца.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Это единичные случаи. Для определения быстрых и долгих продаж следует обратить внимание на значения 25 и 75 квартилей</div>
#
# ✔
# Скорректировала вывод.

# %% [markdown]
# 3. Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
#
# Изучите, зависит ли цена от:
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.

# %%
good_data = data.query('2.5 < last_price < 17 and 30 < total_area < 115')

good_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20      13.000      108.00  2019-03-07T00:00:00      3
# 1                 7       3.350       40.40  2018-12-04T00:00:00      1
# 2                10       5.196       56.00  2015-08-20T00:00:00      2
# 4                 2      10.000      100.00  2018-06-19T00:00:00      2
# 5                10       2.890       30.40  2018-09-10T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23690             3       5.500       52.00  2018-07-19T00:00:00      2
# 23691            11       9.470       72.90  2016-10-13T00:00:00      2
# 23693             9       4.600       62.40  2016-08-05T00:00:00      3
# 23695            14       3.100       59.00  2018-01-15T00:00:00      3
# 23697            13      11.475       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
good_data.pivot_table(index='total_area', values='last_price', aggfunc='median').reset_index().plot(style='o')
# Out:
# <AxesSubplot:>

# %%
(
    good_data.pivot_table(index='total_area', values='last_price', aggfunc='median')
    .plot(style='o', alpha=0.3, grid=True, figsize=(12, 5))
) 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
#
# Напомню, что у каждого графика должны быть подписаны названия и оси</div>

# %%
good_data['last_price'].corr(good_data['total_area'])
# Out:
# 0.7289674547707453

# %% [markdown]
# Существует прямая коррелляция между площадью продаваемого жилья и его ценой.

# %%
(
    data.query('2.5 < last_price < 17 and 15 < living_area < 80')
    .pivot_table(index='living_area', values='last_price', aggfunc='median')
    .plot(style='o', alpha=0.3, grid=True, figsize=(12, 5))
) 
plt.show()

# %%
good_data['last_price'].corr(good_data['living_area'])
# Out:
# 0.5987060279361822

# %% [markdown]
# Существует коррелляция между жилой площадью продаваемого жилья и его ценой.
# Однако цена в меньшей степени зависит от размера жилой площади по сравнению с общей площадью.

# %%
(
    data.query('2.5 < last_price < 17 and 6 < kitchen_area < 16')
    .pivot_table(index='kitchen_area', values='last_price', aggfunc='median')
    .plot(style='o', alpha=0.3, grid=True, figsize=(12, 5))
) 
plt.show()

# %%
good_data['last_price'].corr(good_data['kitchen_area'])
# Out:
# 0.5076802238379072

# %% [markdown]
# Существует коррелляция между площадью кухни продаваемого жилья и его ценой. Однако цена в меньшей степени зависит от площади кухни по сравнению с общей площадью.

# %%
(
    data.query('2.5 < last_price < 17 and 1 < rooms < 6')
    .pivot_table(index='last_price', values='rooms', aggfunc='median')
    .plot(style='o', alpha=0.3, grid=True, figsize=(12, 7))
) 
plt.show()

# %%
good_data['last_price'].corr(good_data['rooms'])
# Out:
# 0.4316885659025005

# %% [markdown]
# Корреляция между кол-вом комнат и ценой есть, но небольшая.

# %%
(
    good_data.pivot_table(index='category_floor', values='last_price', aggfunc='median')
    .plot(kind='bar', grid=True, figsize=(5, 5))
) 

plt.xlabel('Категория этажа')
plt.ylabel('Средняя цена квартиры')

plt.show()

# %% [markdown]
# Квартиры находящиеся в середине дома имеют чуть большую цену по сравнению с квартирами на 1 и последнем этаже.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# При ограниченном количестве значений метрик, таких как количество комнат, категория этажа, а также день, месяц и год размещения объявления, лучше использовать barplot, предварительно рассчитав среднюю цену с группировкой по нужной метрике. Так зависимости будут гораздо нагляднее. Пример написал ниже. </div>
#
# ✔

# %%
# код ревьюера

good_data.query('category_floor != "ошибка"').groupby('category_floor')['last_price'].mean().plot(kind='bar', figsize=(11, 7), color='#73A9AD')

plt.xticks(rotation=0)
plt.title('Средняя цена квартиры в зависимости от категории этажа', size=15)
plt.xlabel('Категория этажа', size=12)
plt.ylabel('Средняя цена квартиры', size=12)

plt.show()

# %%
(
    good_data.pivot_table(index='weekday', values='last_price', aggfunc='median')
    .plot(grid=True, figsize=(7, 5))
) 

plt.xlabel('День недели')
plt.ylabel('Средняя цена квартиры')

plt.show()

# %% [markdown]
# Объявления, данные во вторник, имеют цены чуть выше, чем опубликованные в остальные дни.
# К пятнице цены публикуемых объявлений несколько снижаются.
# В субботу мы наблюдаем небольшое повышение цен, к воскресенью цены в публикуемых объявлениях достигают минимума.

# %%
(
    good_data.pivot_table(index='month', values='last_price', aggfunc='median')
    .plot(grid=True, figsize=(12, 5))
) 

plt.xlabel('Месяц')
plt.ylabel('Средняя цена квартиры')

plt.show()

# %% [markdown]
# В разрезе года квартиры по самым высоким ценам выставляются в апреле.
# Минимальные цены - в июне.

# %%
(
    good_data.pivot_table(index='year', values='last_price', aggfunc='median')
    .plot(grid=True, figsize=(6, 5))
) 

plt.xlabel('Год')
plt.ylabel('Средняя цена квартиры')

plt.show()

# %% [markdown]
# Цены снижались с 2014 по 2016 гг.
# 2016-2017 г. - плато.
# 2017-2019 г. возобновился рост цен.

# %% [markdown]
# 4. Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
cost_rating = good_data.pivot_table(index='locality_name', values='one_metre_cost', aggfunc=['count','mean'])
cost_rating.columns = ['flats_count', 'cost_mean']
cost_rating.sort_values(by='flats_count', ascending=False).head(10)
# Out:
#                    flats_count      cost_mean
# locality_name
# Санкт-Петербург          13865  107869.063366
# Мурино                     486   85476.283374
# поселок Шушары             396   78039.338586
# Пушкин                     331  101917.003142
# Всеволожск                 326   68543.176534
# Колпино                    312   75123.307756
# поселок Парголово          310   90804.800323
# деревня Кудрово            266   91736.480263
# Гатчина                    236   71315.648941
# Петергоф                   179   84878.865307

# %% [markdown]
# Самая высокая стоимость квадратного метра в Санкт-Петербурге (107 869 р/ кв. м.).
#
# Самая низкая стоимость - в Всеволжске (68 543 р/ кв. м.)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Верно</div>

# %% [markdown]
# 5. Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
spb_good_data = good_data.query('locality_name == "Санкт-Петербург" and cityCenters_nearest != 0')
spb_good_data.pivot_table(index='cityCenters_nearest', values='last_price', aggfunc='mean').plot(grid=True, figsize=(30, 10))
plt.show()

# %% [markdown]
# Общее правило для цен на недвижимость в Санкт-Петербурге: чем ближе к центру, тем дороже недвижимость.
# Исключения: расстояние в 20 км. от центра и в 27 км. от центра.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Как ты думаешь, чем можно объяснить данные исключения? </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# Объекты в этих зонах могут находиться достаточно далеко от шумного центра, но с другой стороны - вблизи транспортных развязок. Также это скорее всего новые дома или частный сектор с бОльшими площадями. Все вместе может давать более высокую цену.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# Нами было проведено исследование архива объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# На этапе предобработки данных мы заполнили пропуски в столбцах:
# - locality_name (указали значение - "Санкт-Петербург";
# - floors_total (заполнили медианным значением для каждого населенного пункта);
# - ceiling_height (заполнили медианным значением по домам одинаковой этажности);
# - kitchen_area и living_area (вычислили исходя из общей площади и характерной доли этих помещений в общей площади);
# - balcony (заполнили нулевым значением, т.к. если кол-во не указано, то балконов скорее всего нет);
# - is_apartment (заполнили значением "False", т.к. на рынке преобладают квартиры, а не апартаменты).
#
# Столбцы, данные в которых получены автоматически, остались без изменений.
#
# В некоторых столбцах был изменен тип данных:
# - first_day_exposition с object на datetime для дальнейшей обработки дат;
# - floors_total с float64 на int, т.к. количество этажей - это целое число;
# - balcony с float64 на int, т.к. количество балконов - это целое число;
# - is_apartment с object на bool (т.к. в этом столбце указано наличие или отсутствие свойства продаваемого объекта).
#
# В столбце locality_name были устранены неявные дубликаты - упорядочены все поселки.
#
# Для дальнейшего анализа в базу данных были добавлены дополнительные столбцы:
# - one_metre_cost - стоимость 1 кв. м.;
# - weekday, month, year - выделены из first_day_exposition;
# - categorize_floor - разделили этажи на 3 группы - первый, последний и другие. Также были исправлены ошибки в тех строках, где номер этажа был больше, чем количество этажей в доме.
# + округлили данные до км. в столбце cityCenters_nearest.
#
# На этапе исследовательского анализа данных мы рассматривали каждый из ключевых параметров отдельно.
# Норме соответствуют следующие параметры:
# - total_area: от 30 до 115 кв. м.;
# - living_area: от 10 до 75 кв. м.;
# - kitchen_area: от 5 до 16 кв. м.(на этом этапе нормализовали ряд выбивающихся значений);
# - last_price: от 2,5 до 12 млн. р.;
# - rooms: от 1 до 4 комнат;
# - ceiling_height: от 2,5 до 3,2 м. (на этом этапе нормализовали ряд выбивающихся значений);
# - floors_total: от 1 до 28 этажей;
# - cityCenters_nearest: от 0 до 15 км;
# - parks_nearest: от 0 до 1000 м.
#
# По столбцу days_exposition мы видим, что продажа обычно занимает от 1,5 до 8 месяцев.
# На гистограмме мы видим 2 "плеча":
# - с аномально быстрыми продажами, срок стремится к 0;
# - с аномально долгими продажами, у которых срок превышает 1 год и 3 месяца.
#
# Мы оценили следующие параметры, влияющие на цену объектов:
# - общей площади - чем больше площадь, тем выше цена (зависимость прямая и достаточно сильная);
# - жилой площади - чем больше площадь, тем выше цена (влияние фактора слабее, чем влияние общей площади);
# - площади кухни - чем больше площадь, тем выше цена (влияние фактора слабее, чем влияние жилой площади);
# - количества комнат - связь слабая;
# - этажа, на котором расположена квартира - квартиры находящиеся в середине дома имеют бОльшую цену по сравнению с квартирами на 1 и последнем этаже;
# - даты размещения (день недели, месяц, год): наибольшую выручку принесли объявления, опубликованные по вторникам. В разрезе года квартиры по самым высоким ценам выставляются в апреле, минимальные цены - в июне. Цены снижались с 2014 по 2016 гг. 2016-2017 г. - вышли на плато. 2017-2019 г. возобновился рост цен.
#
# Мы составили рейтинг из 10 населённых пунктов с наибольшим числом объявлений. Среди них самая высокая стоимость квадратного метра в Санкт-Петербурге (107 869 р/ кв. м.), самая низкая стоимость - в Всеволжске (68 543 р/ кв. м.).
#
# Общее правило для цен на недвижимость в Санкт-Петербурге: чем ближе к центру, тем дороже недвижимость.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
#
# Хороший итоговый вывод!
#
#
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**
# </div>
#
# ✔

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x] Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
